# %%
# !pip install torch==2.2
# !pip install torchvision==0.17

# !pip install nltk==3.7
# Out:
# Requirement already satisfied: torch==2.2 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: filelock in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (4.11.0)
# Requirement already satisfied: sympy in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (1.12)
# Requirement already satisfied: networkx in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (3.1)
# Requirement already satisfied: jinja2 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (3.1.3)
# Requirement already satisfied: fsspec in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from jinja2->torch==2.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from sympy->torch==2.2) (1.3.0)
# Requirement already satisfied: torchvision==0.17 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (0.17.0)
# Requirement already satisfied: numpy in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torchvision==0.17) (1.26.4)
# Requirement already satisfied: requests in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torchvision==0.17) (2.31.0)
# Requirement already satisfied: torch==2.2.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torchvision==0.17) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torchvision==0.17) (10.3.0)
# Requirement already satisfied: filelock in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (4.11.0)
# Requirement already satisfied: sympy in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (1.12)
# Requirement already satisfied: networkx in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (3.1)
# Requirement already satisfied: jinja2 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (3.1.3)
# Requirement already satisfied: fsspec in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from torch==2.2.0->torchvision==0.17) (2024.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from requests->torchvision==0.17) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from requests->torchvision==0.17) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from requests->torchvision==0.17) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from requests->torchvision==0.17) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from jinja2->torch==2.2.0->torchvision==0.17) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from sympy->torch==2.2.0->torchvision==0.17) (1.3.0)
# Requirement already satisfied: nltk==3.7 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: click in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from nltk==3.7) (8.1.7)
# Requirement already satisfied: joblib in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from nltk==3.7) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from nltk==3.7) (2024.7.24)
# Requirement already satisfied: tqdm in /Users/koyiljonvaliev/Anaconda/anaconda3/envs/TorchEnv/lib/python3.9/site-packages (from nltk==3.7) (4.66.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms

torch.use_deterministic_algorithms(True)

# %%
class LeNet(nn.Module):

    def __init__(self):
        super(LeNet, self).__init__()
        # 3 input image channel, 6 output feature maps and 5x5 conv kernel
        self.cn1 = nn.Conv2d(3, 6, 5)
        # 6 input image channel, 16 output feature maps and 5x5 conv kernel
        self.cn2 = nn.Conv2d(6, 16, 5)
        # fully connected layers of size 120, 84 and 10
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # 5*5 is the spatial dimension at this layer
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        # Convolution with 5x5 kernel
        x = F.relu(self.cn1(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Convolution with 5x5 kernel
        x = F.relu(self.cn2(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Flatten spatial and depth dimensions into a single vector
        x = x.view(-1, self.flattened_features(x))
        # Fully connected operations
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def flattened_features(self, x):
        # all except the first (batch) dimension
        size = x.size()[1:]  
        num_feats = 1
        for s in size:
            num_feats *= s
        return num_feats


lenet = LeNet()
print(lenet)
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def train(net, trainloader, optim, epoch):
    # initialize loss
    loss_total = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # ip refers to the input images, and ground_truth refers to the output classes the images belong to
        ip, ground_truth = data

        # zero the parameter gradients
        optim.zero_grad()

        # forward pass + backward pass + optimization step
        op = net(ip)
        loss = nn.CrossEntropyLoss()(op, ground_truth)
        loss.backward()
        optim.step()

        # update loss
        loss_total += loss.item()
        
        # print loss statistics
        if (i+1) % 1000 == 0:    # print at the interval of 1000 mini-batches
            print('[Epoch number : %d, Mini-batches: %5d] loss: %.3f' %
                  (epoch + 1, i + 1, loss_total / 200))
            loss_total = 0.0

# %%
def test(net, testloader):
    success = 0
    counter = 0
    with torch.no_grad():
        for data in testloader:
            im, ground_truth = data
            op = net(im)
            _, pred = torch.max(op.data, 1)
            counter += ground_truth.size(0)
            success += (pred == ground_truth).sum().item()

    print('LeNet accuracy on 10000 images from test dataset: %d %%' % (
        100 * success / counter))

# %%
# The mean and std are kept as 0.5 for normalizing pixel values as the pixel values are originally in the range 0 to 1
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomCrop(32, 4),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True)


test_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=10000, shuffle=False)


# ordering is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:19<00:00, 8748707.81it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
trainloader.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 trainloader.shape
#
# AttributeError: 'DataLoader' object has no attribute 'shape'

# %%
# define a function that displays an image
def imageshow(image):
    # un-normalize the image
    image = image/2 + 0.5     
    npimage = image.numpy()
    plt.imshow(np.transpose(npimage, (1, 2, 0)))
    plt.show()


# sample images from training set
dataiter = iter(trainloader)
images, labels = next(dataiter)

# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print labels
print('    '+'  ||  '.join(classes[labels[j]] for j in range(num_images)))
# Out:
#     dog  ||  plane  ||  cat  ||  bird

# %%
# define optimizer
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)

# training loop over the dataset multiple times
for epoch in range(50):  
    train(lenet, trainloader, optim, epoch)
    print()
    test(lenet, testloader)
    print()

print('Finished Training')
# Out:
# [Epoch number : 1, Mini-batches:  1000] loss: 9.922
# [Epoch number : 1, Mini-batches:  2000] loss: 8.898
# [Epoch number : 1, Mini-batches:  3000] loss: 8.233
# [Epoch number : 1, Mini-batches:  4000] loss: 8.016
# [Epoch number : 1, Mini-batches:  5000] loss: 7.704
# [Epoch number : 1, Mini-batches:  6000] loss: 7.673
#
# LeNet accuracy on 10000 images from test dataset: 48 %
#
# [Epoch number : 2, Mini-batches:  1000] loss: 7.466
# [Epoch number : 2, Mini-batches:  2000] loss: 7.347
# [Epoch number : 2, Mini-batches:  3000] loss: 7.142
# [Epoch number : 2, Mini-batches:  4000] loss: 7.091
# [Epoch number : 2, Mini-batches:  5000] loss: 6.937
# [Epoch number : 2, Mini-batches:  6000] loss: 6.957
#
# LeNet accuracy on 10000 images from test dataset: 53 %
#
# [Epoch number : 3, Mini-batches:  1000] loss: 6.870
# [Epoch number : 3, Mini-batches:  2000] loss: 6.742
# [Epoch number : 3, Mini-batches:  3000] loss: 6.698
# [Epoch number : 3, Mini-batches:  4000] loss: 6.753
# [Epoch number : 3, Mini-batches:  5000] loss: 6.531
# [Epoch number : 3, Mini-batches:  6000] loss: 6.530
#
# LeNet accuracy on 10000 images from test dataset: 57 %
#
# [Epoch number : 4, Mini-batches:  1000] loss: 6.485
# [Epoch number : 4, Mini-batches:  2000] loss: 6.544
# [Epoch number : 4, Mini-batches:  3000] loss: 6.446
# [Epoch number : 4, Mini-batches:  4000] loss: 6.273
# [Epoch number : 4, Mini-batches:  5000] loss: 6.329
# [Epoch number : 4, Mini-batches:  6000] loss: 6.397
#
# LeNet accuracy on 10000 images from test dataset: 57 %
#
# [Epoch number : 5, Mini-batches:  1000] loss: 6.223
# [Epoch number : 5, Mini-batches:  2000] loss: 6.247
# [Epoch number : 5, Mini-batches:  3000] loss: 6.263
# [Epoch number : 5, Mini-batches:  4000] loss: 6.157
# [Epoch number : 5, Mini-batches:  5000] loss: 6.278
# [Epoch number : 5, Mini-batches:  6000] loss: 6.304
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 6, Mini-batches:  1000] loss: 6.239
# [Epoch number : 6, Mini-batches:  2000] loss: 6.002
# [Epoch number : 6, Mini-batches:  3000] loss: 6.093
# [Epoch number : 6, Mini-batches:  4000] loss: 6.212
# [Epoch number : 6, Mini-batches:  5000] loss: 6.112
# [Epoch number : 6, Mini-batches:  6000] loss: 6.074
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 7, Mini-batches:  1000] loss: 6.038
# [Epoch number : 7, Mini-batches:  2000] loss: 6.028
# [Epoch number : 7, Mini-batches:  3000] loss: 6.084
# [Epoch number : 7, Mini-batches:  4000] loss: 5.968
# [Epoch number : 7, Mini-batches:  5000] loss: 6.029
# [Epoch number : 7, Mini-batches:  6000] loss: 5.943
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 8, Mini-batches:  1000] loss: 5.949
# [Epoch number : 8, Mini-batches:  2000] loss: 6.024
# [Epoch number : 8, Mini-batches:  3000] loss: 5.867
# [Epoch number : 8, Mini-batches:  4000] loss: 5.924
# [Epoch number : 8, Mini-batches:  5000] loss: 5.946
# [Epoch number : 8, Mini-batches:  6000] loss: 5.891
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 9, Mini-batches:  1000] loss: 5.979
# [Epoch number : 9, Mini-batches:  2000] loss: 5.832
# [Epoch number : 9, Mini-batches:  3000] loss: 5.979
# [Epoch number : 9, Mini-batches:  4000] loss: 5.905
# [Epoch number : 9, Mini-batches:  5000] loss: 5.841
# [Epoch number : 9, Mini-batches:  6000] loss: 5.876
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 10, Mini-batches:  1000] loss: 5.793
# [Epoch number : 10, Mini-batches:  2000] loss: 5.876
# [Epoch number : 10, Mini-batches:  3000] loss: 5.872
# [Epoch number : 10, Mini-batches:  4000] loss: 5.892
# [Epoch number : 10, Mini-batches:  5000] loss: 5.709
# [Epoch number : 10, Mini-batches:  6000] loss: 5.860
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 11, Mini-batches:  1000] loss: 5.803
# [Epoch number : 11, Mini-batches:  2000] loss: 5.683
# [Epoch number : 11, Mini-batches:  3000] loss: 5.848
# [Epoch number : 11, Mini-batches:  4000] loss: 5.749
# [Epoch number : 11, Mini-batches:  5000] loss: 5.701
# [Epoch number : 11, Mini-batches:  6000] loss: 5.712
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 12, Mini-batches:  1000] loss: 5.753
# [Epoch number : 12, Mini-batches:  2000] loss: 5.711
# [Epoch number : 12, Mini-batches:  3000] loss: 5.684
# [Epoch number : 12, Mini-batches:  4000] loss: 5.732
# [Epoch number : 12, Mini-batches:  5000] loss: 5.729
# [Epoch number : 12, Mini-batches:  6000] loss: 5.716
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 13, Mini-batches:  1000] loss: 5.688
# [Epoch number : 13, Mini-batches:  2000] loss: 5.608
# [Epoch number : 13, Mini-batches:  3000] loss: 5.657
# [Epoch number : 13, Mini-batches:  4000] loss: 5.643
# [Epoch number : 13, Mini-batches:  5000] loss: 5.768
# [Epoch number : 13, Mini-batches:  6000] loss: 5.735
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 14, Mini-batches:  1000] loss: 5.747
# [Epoch number : 14, Mini-batches:  2000] loss: 5.601
# [Epoch number : 14, Mini-batches:  3000] loss: 5.637
# [Epoch number : 14, Mini-batches:  4000] loss: 5.696
# [Epoch number : 14, Mini-batches:  5000] loss: 5.605
# [Epoch number : 14, Mini-batches:  6000] loss: 5.739
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 15, Mini-batches:  1000] loss: 5.578
# [Epoch number : 15, Mini-batches:  2000] loss: 5.600
# [Epoch number : 15, Mini-batches:  3000] loss: 5.598
# [Epoch number : 15, Mini-batches:  4000] loss: 5.571
# [Epoch number : 15, Mini-batches:  5000] loss: 5.456
# [Epoch number : 15, Mini-batches:  6000] loss: 5.621
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 16, Mini-batches:  1000] loss: 5.569
# [Epoch number : 16, Mini-batches:  2000] loss: 5.433
# [Epoch number : 16, Mini-batches:  3000] loss: 5.589
# [Epoch number : 16, Mini-batches:  4000] loss: 5.530
# [Epoch number : 16, Mini-batches:  5000] loss: 5.558
# [Epoch number : 16, Mini-batches:  6000] loss: 5.604
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 17, Mini-batches:  1000] loss: 5.481
# [Epoch number : 17, Mini-batches:  2000] loss: 5.422
# [Epoch number : 17, Mini-batches:  3000] loss: 5.606
# [Epoch number : 17, Mini-batches:  4000] loss: 5.545
# [Epoch number : 17, Mini-batches:  5000] loss: 5.596
# [Epoch number : 17, Mini-batches:  6000] loss: 5.546
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 18, Mini-batches:  1000] loss: 5.508
# [Epoch number : 18, Mini-batches:  2000] loss: 5.515
# [Epoch number : 18, Mini-batches:  3000] loss: 5.511
# [Epoch number : 18, Mini-batches:  4000] loss: 5.409
# [Epoch number : 18, Mini-batches:  5000] loss: 5.511
# [Epoch number : 18, Mini-batches:  6000] loss: 5.582
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 19, Mini-batches:  1000] loss: 5.437
# [Epoch number : 19, Mini-batches:  2000] loss: 5.425
# [Epoch number : 19, Mini-batches:  3000] loss: 5.540
# [Epoch number : 19, Mini-batches:  4000] loss: 5.492
# [Epoch number : 19, Mini-batches:  5000] loss: 5.417
# [Epoch number : 19, Mini-batches:  6000] loss: 5.502
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 20, Mini-batches:  1000] loss: 5.450
# [Epoch number : 20, Mini-batches:  2000] loss: 5.300
# [Epoch number : 20, Mini-batches:  3000] loss: 5.315
# [Epoch number : 20, Mini-batches:  4000] loss: 5.487
# [Epoch number : 20, Mini-batches:  5000] loss: 5.401
# [Epoch number : 20, Mini-batches:  6000] loss: 5.624
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 21, Mini-batches:  1000] loss: 5.448
# [Epoch number : 21, Mini-batches:  2000] loss: 5.466
# [Epoch number : 21, Mini-batches:  3000] loss: 5.332
# [Epoch number : 21, Mini-batches:  4000] loss: 5.478
# [Epoch number : 21, Mini-batches:  5000] loss: 5.429
# [Epoch number : 21, Mini-batches:  6000] loss: 5.495
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 22, Mini-batches:  1000] loss: 5.384
# [Epoch number : 22, Mini-batches:  2000] loss: 5.482
# [Epoch number : 22, Mini-batches:  3000] loss: 5.428
# [Epoch number : 22, Mini-batches:  4000] loss: 5.396
# [Epoch number : 22, Mini-batches:  5000] loss: 5.448
# [Epoch number : 22, Mini-batches:  6000] loss: 5.404
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 23, Mini-batches:  1000] loss: 5.416
# [Epoch number : 23, Mini-batches:  2000] loss: 5.434
# [Epoch number : 23, Mini-batches:  3000] loss: 5.410
# [Epoch number : 23, Mini-batches:  4000] loss: 5.361
# [Epoch number : 23, Mini-batches:  5000] loss: 5.384
# [Epoch number : 23, Mini-batches:  6000] loss: 5.354
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 24, Mini-batches:  1000] loss: 5.272
# [Epoch number : 24, Mini-batches:  2000] loss: 5.466
# [Epoch number : 24, Mini-batches:  3000] loss: 5.424
# [Epoch number : 24, Mini-batches:  4000] loss: 5.476
# [Epoch number : 24, Mini-batches:  5000] loss: 5.263
# [Epoch number : 24, Mini-batches:  6000] loss: 5.374
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 25, Mini-batches:  1000] loss: 5.392
# [Epoch number : 25, Mini-batches:  2000] loss: 5.328
# [Epoch number : 25, Mini-batches:  3000] loss: 5.470
# [Epoch number : 25, Mini-batches:  4000] loss: 5.349
# [Epoch number : 25, Mini-batches:  5000] loss: 5.442
# [Epoch number : 25, Mini-batches:  6000] loss: 5.292
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 26, Mini-batches:  1000] loss: 5.306
# [Epoch number : 26, Mini-batches:  2000] loss: 5.277
# [Epoch number : 26, Mini-batches:  3000] loss: 5.447
# [Epoch number : 26, Mini-batches:  4000] loss: 5.220
# [Epoch number : 26, Mini-batches:  5000] loss: 5.281
# [Epoch number : 26, Mini-batches:  6000] loss: 5.381
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 27, Mini-batches:  1000] loss: 5.329
# [Epoch number : 27, Mini-batches:  2000] loss: 5.329
# [Epoch number : 27, Mini-batches:  3000] loss: 5.292
# [Epoch number : 27, Mini-batches:  4000] loss: 5.344
# [Epoch number : 27, Mini-batches:  5000] loss: 5.411
# [Epoch number : 27, Mini-batches:  6000] loss: 5.317
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 28, Mini-batches:  1000] loss: 5.273
# [Epoch number : 28, Mini-batches:  2000] loss: 5.241
# [Epoch number : 28, Mini-batches:  3000] loss: 5.317
# [Epoch number : 28, Mini-batches:  4000] loss: 5.239
# [Epoch number : 28, Mini-batches:  5000] loss: 5.301
# [Epoch number : 28, Mini-batches:  6000] loss: 5.386
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 29, Mini-batches:  1000] loss: 5.392
# [Epoch number : 29, Mini-batches:  2000] loss: 5.286
# [Epoch number : 29, Mini-batches:  3000] loss: 5.232
# [Epoch number : 29, Mini-batches:  4000] loss: 5.225
# [Epoch number : 29, Mini-batches:  5000] loss: 5.340
# [Epoch number : 29, Mini-batches:  6000] loss: 5.170
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 30, Mini-batches:  1000] loss: 5.207
# [Epoch number : 30, Mini-batches:  2000] loss: 5.213
# [Epoch number : 30, Mini-batches:  3000] loss: 5.247
# [Epoch number : 30, Mini-batches:  4000] loss: 5.256
# [Epoch number : 30, Mini-batches:  5000] loss: 5.206
# [Epoch number : 30, Mini-batches:  6000] loss: 5.338
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 31, Mini-batches:  1000] loss: 5.187
# [Epoch number : 31, Mini-batches:  2000] loss: 5.312
# [Epoch number : 31, Mini-batches:  3000] loss: 5.202
# [Epoch number : 31, Mini-batches:  4000] loss: 5.132
# [Epoch number : 31, Mini-batches:  5000] loss: 5.231
# [Epoch number : 31, Mini-batches:  6000] loss: 5.285
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 32, Mini-batches:  1000] loss: 5.205
# [Epoch number : 32, Mini-batches:  2000] loss: 5.293
# [Epoch number : 32, Mini-batches:  3000] loss: 5.246
# [Epoch number : 32, Mini-batches:  4000] loss: 5.298
# [Epoch number : 32, Mini-batches:  5000] loss: 5.257
# [Epoch number : 32, Mini-batches:  6000] loss: 5.204
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 33, Mini-batches:  1000] loss: 5.127
# [Epoch number : 33, Mini-batches:  2000] loss: 5.370
# [Epoch number : 33, Mini-batches:  3000] loss: 5.196
# [Epoch number : 33, Mini-batches:  4000] loss: 5.149
# [Epoch number : 33, Mini-batches:  5000] loss: 5.307
# [Epoch number : 33, Mini-batches:  6000] loss: 5.226
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 34, Mini-batches:  1000] loss: 5.119
# [Epoch number : 34, Mini-batches:  2000] loss: 5.131
# [Epoch number : 34, Mini-batches:  3000] loss: 5.244
# [Epoch number : 34, Mini-batches:  4000] loss: 5.206
# [Epoch number : 34, Mini-batches:  5000] loss: 5.220
# [Epoch number : 34, Mini-batches:  6000] loss: 5.199
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 35, Mini-batches:  1000] loss: 5.123
# [Epoch number : 35, Mini-batches:  2000] loss: 5.161
# [Epoch number : 35, Mini-batches:  3000] loss: 5.187
# [Epoch number : 35, Mini-batches:  4000] loss: 5.212
# [Epoch number : 35, Mini-batches:  5000] loss: 5.169
# [Epoch number : 35, Mini-batches:  6000] loss: 5.174
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 36, Mini-batches:  1000] loss: 5.118
# [Epoch number : 36, Mini-batches:  2000] loss: 5.187
# [Epoch number : 36, Mini-batches:  3000] loss: 5.183
# [Epoch number : 36, Mini-batches:  4000] loss: 5.180
# [Epoch number : 36, Mini-batches:  5000] loss: 5.269
# [Epoch number : 36, Mini-batches:  6000] loss: 5.116
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 37, Mini-batches:  1000] loss: 5.128
# [Epoch number : 37, Mini-batches:  2000] loss: 5.121
# [Epoch number : 37, Mini-batches:  3000] loss: 5.159
# [Epoch number : 37, Mini-batches:  4000] loss: 5.262
# [Epoch number : 37, Mini-batches:  5000] loss: 5.241
# [Epoch number : 37, Mini-batches:  6000] loss: 5.255
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 38, Mini-batches:  1000] loss: 5.122
# [Epoch number : 38, Mini-batches:  2000] loss: 5.148
# [Epoch number : 38, Mini-batches:  3000] loss: 5.122
# [Epoch number : 38, Mini-batches:  4000] loss: 5.264
# [Epoch number : 38, Mini-batches:  5000] loss: 5.186
# [Epoch number : 38, Mini-batches:  6000] loss: 5.250
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 39, Mini-batches:  1000] loss: 5.168
# [Epoch number : 39, Mini-batches:  2000] loss: 5.279
# [Epoch number : 39, Mini-batches:  3000] loss: 5.162
# [Epoch number : 39, Mini-batches:  4000] loss: 5.235
# [Epoch number : 39, Mini-batches:  5000] loss: 5.174
# [Epoch number : 39, Mini-batches:  6000] loss: 5.126
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 40, Mini-batches:  1000] loss: 5.133
# [Epoch number : 40, Mini-batches:  2000] loss: 5.156
# [Epoch number : 40, Mini-batches:  3000] loss: 5.206
# [Epoch number : 40, Mini-batches:  4000] loss: 5.254
# [Epoch number : 40, Mini-batches:  5000] loss: 5.144
# [Epoch number : 40, Mini-batches:  6000] loss: 5.213
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 41, Mini-batches:  1000] loss: 5.015
# [Epoch number : 41, Mini-batches:  2000] loss: 5.176
# [Epoch number : 41, Mini-batches:  3000] loss: 5.112
# [Epoch number : 41, Mini-batches:  4000] loss: 5.148
# [Epoch number : 41, Mini-batches:  5000] loss: 5.125
# [Epoch number : 41, Mini-batches:  6000] loss: 5.078
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 42, Mini-batches:  1000] loss: 5.176
# [Epoch number : 42, Mini-batches:  2000] loss: 5.108
# [Epoch number : 42, Mini-batches:  3000] loss: 5.201
# [Epoch number : 42, Mini-batches:  4000] loss: 5.165
# [Epoch number : 42, Mini-batches:  5000] loss: 5.075
# [Epoch number : 42, Mini-batches:  6000] loss: 5.139
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 43, Mini-batches:  1000] loss: 5.072
# [Epoch number : 43, Mini-batches:  2000] loss: 5.022
# [Epoch number : 43, Mini-batches:  3000] loss: 5.059
# [Epoch number : 43, Mini-batches:  4000] loss: 5.103
# [Epoch number : 43, Mini-batches:  5000] loss: 5.249
# [Epoch number : 43, Mini-batches:  6000] loss: 5.252
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 44, Mini-batches:  1000] loss: 5.021
# [Epoch number : 44, Mini-batches:  2000] loss: 5.107
# [Epoch number : 44, Mini-batches:  3000] loss: 5.181
# [Epoch number : 44, Mini-batches:  4000] loss: 5.133
# [Epoch number : 44, Mini-batches:  5000] loss: 5.184
# [Epoch number : 44, Mini-batches:  6000] loss: 5.123
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 45, Mini-batches:  1000] loss: 5.124
# [Epoch number : 45, Mini-batches:  2000] loss: 5.150
# [Epoch number : 45, Mini-batches:  3000] loss: 5.135
# [Epoch number : 45, Mini-batches:  4000] loss: 5.117
# [Epoch number : 45, Mini-batches:  5000] loss: 5.153
# [Epoch number : 45, Mini-batches:  6000] loss: 5.094
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 46, Mini-batches:  1000] loss: 5.059
# [Epoch number : 46, Mini-batches:  2000] loss: 5.043
# [Epoch number : 46, Mini-batches:  3000] loss: 5.001
# [Epoch number : 46, Mini-batches:  4000] loss: 5.087
# [Epoch number : 46, Mini-batches:  5000] loss: 5.212
# [Epoch number : 46, Mini-batches:  6000] loss: 5.151
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 47, Mini-batches:  1000] loss: 5.166
# [Epoch number : 47, Mini-batches:  2000] loss: 5.087
# [Epoch number : 47, Mini-batches:  3000] loss: 5.033
# [Epoch number : 47, Mini-batches:  4000] loss: 5.093
# [Epoch number : 47, Mini-batches:  5000] loss: 5.059
# [Epoch number : 47, Mini-batches:  6000] loss: 5.098
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 48, Mini-batches:  1000] loss: 5.197
# [Epoch number : 48, Mini-batches:  2000] loss: 5.172
# [Epoch number : 48, Mini-batches:  3000] loss: 5.215
# [Epoch number : 48, Mini-batches:  4000] loss: 5.104
# [Epoch number : 48, Mini-batches:  5000] loss: 5.133
# [Epoch number : 48, Mini-batches:  6000] loss: 5.149
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 49, Mini-batches:  1000] loss: 5.139
# [Epoch number : 49, Mini-batches:  2000] loss: 5.097
# [Epoch number : 49, Mini-batches:  3000] loss: 5.166
# [Epoch number : 49, Mini-batches:  4000] loss: 5.160
# [Epoch number : 49, Mini-batches:  5000] loss: 5.154
# [Epoch number : 49, Mini-batches:  6000] loss: 5.122
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 50, Mini-batches:  1000] loss: 5.120
# [Epoch number : 50, Mini-batches:  2000] loss: 5.002
# [Epoch number : 50, Mini-batches:  3000] loss: 5.135
# [Epoch number : 50, Mini-batches:  4000] loss: 5.174
# [Epoch number : 50, Mini-batches:  5000] loss: 5.124
# [Epoch number : 50, Mini-batches:  6000] loss: 5.082
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# Finished Training

# %%
model_path = './cifar_model.pth'
torch.save(lenet.state_dict(), model_path)

# %%
# load test dataset images
d_iter = iter(testloader)
im, ground_truth = next(d_iter)

# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:      ', ' '.join('%5s' % classes[ground_truth[j]] for j in range(4)))

# load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(model_path))

# model inference
op = lenet_cached(im)

# print predictions
_, pred = torch.max(op, 1)

print('Prediction: ', ' '.join('%5s' % classes[pred[j]] for j in range(4)))
# Out:
# Label:         cat  ship  ship plane
# Prediction:    cat  ship  ship plane

# %%
success = 0
counter = 0
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op.data, 1)
        counter += ground_truth.size(0)
        success += (pred == ground_truth).sum().item()

print('Model accuracy on 10000 images from test dataset: %d %%' % (
    100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 68 %

# %%
class_sucess = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op, 1)
        c = (pred == ground_truth).squeeze()
        for i in range(10000):
            ground_truth_curr = ground_truth[i]
            class_sucess[ground_truth_curr] += c[i].item()
            class_counter[ground_truth_curr] += 1


for i in range(10):
    print('Model accuracy for class %5s : %2d %%' % (
        classes[i], 100 * class_sucess[i] / class_counter[i]))
# Out:
# Model accuracy for class plane : 70 %
# Model accuracy for class   car : 84 %
# Model accuracy for class  bird : 60 %
# Model accuracy for class   cat : 57 %
# Model accuracy for class  deer : 60 %
# Model accuracy for class   dog : 48 %
# Model accuracy for class  frog : 79 %
# Model accuracy for class horse : 68 %
# Model accuracy for class  ship : 76 %
# Model accuracy for class truck : 76 %
